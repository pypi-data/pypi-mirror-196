# %%
# %matplotlib notebook

import jscatter as js

# nglview for viewing universes
import nglview as nv

# for additional MDAnalysis funtionality if needed
# import MDAnalysis as mda

# %%
# create universe with protein inside that adds hydrogens
u = js.bio.scatteringUniverse('3cln_h.pdb')
# select protein atoms
protein = u.select_atoms("protein")
# Out:
# Used PyMol to add hydrogens.

# %%
# create viewer
w = nv.show_mdanalysis(protein)
# show it
w
# Out:
# NGLWidget()

# %%
u.qlist = js.loglist(0.1,5,100) 
# calc SANS scattering without surface
S = js.bio.scatIntUniv(protein, error=100)
# Out:
# mode is  n
# No surface layer
# unit is nm^2/particle
# start integrating with 2183 atoms

# %%
# plot it
p=js.mplot()
p.Plot(S)
p.Xaxis(label='$Q\, /\, nm^{-1}$')
p.Yaxis(label='$F(Q)\, /\, nm^{2}/particle $')
# Out:
# <img src="data:image/png;base64,..." width="405">
